# %% [markdown]
# ## Class relationship
# `1. Aggregation` <br />
# `2. Inheritance`

# %% [markdown]
# ## `1. aggregation (Has-A-relationship)`

# %%
class Customer:

    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address
    
    def print_address(self):
        print(self.address.get_city(),self.address.pin,self.address.state)

    # using method of class Address in the class Customerp
    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.edit_address(new_city,new_pin,new_state)

class Address:

    def __init__(self,city,pincode,state):
        self.__city = city
        self.pin = pincode
        self.state = state

    def get_city(self):
        return self.__city
    
    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state

address = Address("Attariya",10141,'Sudurpaschim')
#passing address object of class Address as a argument in Customer class
cust = Customer('Lokesh','male',address)


cust.print_address()

cust.edit_profile('Dipesh','Dhangadhi',1111,'Sudurpaschim')
cust.print_address()
# Out:
# Attariya 10141 Sudurpaschim
# Dhangadhi 1111 Sudurpaschim

# %% [markdown]
# ## `2. Inheritance`

# %%
#Parent class
class User:

    def __init__(self):
        self.name ='Lokesh'
        self.gender = 'male'

    def login(self):
        print('Login')

#Child class
class Student(User):
    def enroll(self):
        print('enroll into the course')

u = User()
s= Student()

print(s.name)

s.login()
s.enroll()
# Out:
# Lokesh
# Login
# enroll into the course

# %% [markdown]
# ### `What gets inherited?`
# - Constructor
# - Non private attribute
# - non private methods

# %%
#how constructor is inherited
#example 1 
class Phone:

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):
    pass

s= Smartphone(20000,'Iphone', '13mp')
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
#example 2
class Phone:
    
    #this constructor is not excuted so the variables are not stored in the memory so while trying to access the variables with the object of smartphone class it will throw an error. because the variables do not exists for the smartphone class

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):
    def __init__(self,os,ram):
        self.os = os
        self.ram = ram
        print("Inside class smartphone")

    def buy(self):
        print("Buying a smartphone")
#the constructor of the smartphone class is called not the Phone class constructor, 
s =Smartphone("Android",2)
# Out:
# Inside class smartphone

# %%
# concept of non private variables and  methods
#Example1: child cant acces private members of the class
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
    
    #getter
    def show(self):
        print(self.__price)

class Smartphone(Phone):
    def check(self):
        print(self.__price)

s=Smartphone(20000,'Apple',13)
print(s.brand)

#s.check()      # -> this will not work as it is trying to access private member of parent class
s.show()
# Out:
# Inside phone constructor
# Apple
# 20000

# %%
#practice question. What wil be the output?

class Parent:
    def __init__(self,num):
        self.__num = num
    
    def get_num(self):
        return self.__num
    
class Child(Parent):

    def show(self):
        print("This is in child class")

son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
#question 2. What will be the output?
class Parent:
    def __init__(self,num):
        self.__num = num
    
    def get_num(self):
        return self.__num
    
class Child(Parent):

    def __init__(self,val,num):
        self.__val = val

    def get_val(self):
        return self.__val

son=Child(100,10)
print("Parent: Num:", son.get_num())
print("Child: val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 18
#      15         return self.__val
#      17 son=Child(100,10)
# ---> 18 print("Parent: Num:", son.get_num())
#      19 print("Child: val:",son.get_val())
#
# Cell In[23], line 7, in Parent.get_num(self)
#       6 def get_num(self):
# ----> 7     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
#question 3. What will be the output?
class A:
    def __init__(self):
        self.var1 = 100
    
    def display1(self,var1):
        print("class A :",self.var1)

class B(A):

    def display2(self, var1):
        print("class B:", self.var1)

obj = B()
obj.display1(200)
# Out:
# class B: 100

# %%
#concept of method overriding

class Phone:
    
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):

    def buy(self):
        print("Buying a smartphone")
s=Smartphone(2000, "Apple", 13)
s.buy() # childs buy method is excuted always. It overrides the Parent's method
# Out:
# Inside phone constructor
# Buying a smartphone

# %%
#super keyword concept
#concept of method overriding

class Phone:
    
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):

    def buy(self):
        print("Buying a smartphone")
        #syntax to call parent's buy method
        super().buy()

s=Smartphone(2000, "Apple", 13)
s.buy() # childs buy method is excuted slways
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
#Concept of super keyword using constructor

#example 2
class Phone:
    
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

class Smartphone(Phone):
    def __init__(self,price,brand,camera,os,ram):
        print("Inside class smartphone")
        super().__init__(price, brand, camera)  #it will call parents constructor
        self.os = os
        self.ram = ram
        

s =Smartphone(20000,"Samgsung",12,"Android",2)    
print(s.os)
print(s.brand)
# Out:
# Inside class smartphone
# Inside phone constructor
# Android
# Samgsung

# %% [markdown]
# ### `Summmary of inheritance`
# - A class can be inherit from another class
# - Inheritance improves code reusability
# - Constructor, attributes, methods get inherited to the child class
# - The parent has no access to the child class
# - Private properties of parent are not accessible directly in child class
# - Child class can override the attributes or methods. This is called method overriding
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
# Question1 What is the output?

class Parent:
    def __init__(self,num):
        self.__num = num
    
    def get_num(self):
        return self.__num

class Child(Parent):
    def __init__(self, num,val):   #this is called
        super().__init__(num)   ## this calls parents init
        self.__val = val
    
    def get_val(self):
        return self.__val

son = Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
# Question 2 . Guess the output?

class Parent:
    def __init__(self):
        self.num = 100

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.var = 200
    
    def show(self):
        print(self.num)
        print(self.var)

son = Child()
son.show()
# Out:
# 100
# 200

# %%
#Question 3. Guess the output?

class Parent:
    def __init__(self):
        self.__num = 100

    def show(self):
        print("Parent: ",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var = 200
    
    def show(self):
        print("child :",self.__var)

son = Child()
son.show()
# Out:
# child : 200

# %% [markdown]
# ### `Types of Inheritance`
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance (Diamond Problem)
# - Hybrid Inheritance

# %%
# 1. Single Inheritance
class Phone:

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):   # -> single parent Phone of the class Smartphone
    pass

s= Smartphone(20000,'Iphone', '13mp').buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
#2. Multilevel Inheritance
class Product:
    def review(self):
        print("Produt customer review")

class Phone(Product): # Phone inherits the Product

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):  # Smartphone Inherits the Phone
    pass

s= Smartphone(20000,'Iphone', '13mp')
s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Produt customer review

# %%
#Hierarchical Inheritance

class Phone:  # One parent Class

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone): # 1st child class
    pass

class FeaturePhone(Phone): # 2nd child class
    pass

Smartphone(20000,'Iphone', '13mp').buy()
FeaturePhone(1000,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
#Multiple Inheritance
class Product:   # parent ckass 1
    def review(self):
        print("Produt customer review")

class Phone:  # parent class 2

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone, Product):  # child class
    pass

s= Smartphone(20000,'Iphone', '13mp')
s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Produt customer review

# %%
#The diamond problem of multiple Inheritance
class Product:
    def buy(self):
        print("Produt customer review")

class Phone:

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

#Method resolution order
class Smartphone(Phone, Product):
    pass

s= Smartphone(20000,'Iphone', '13mp')
#  class Smartphone(Phone, Product)
#phone is written first so Phone's buy method will be executed
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# Q1 Whar will be the output
class A:
    def m1(self):
        return 20
    
class B(A):
    def m1(self):
        return 30
    
    def m2(self):
        return 40
    
class C(B):
    def m2(self):
        return 20

obj1 = A()
obj2 = B()
obj3 = C()

print(obj1.m1()+obj3.m1()+obj3.m2())
# Out:
# 70

# %%
#Q2 What will be output

class A:

    def m1(self):
        return 20
    
class B(A):
     
     def m1(self):
         val =super().m1() + 30
         return val
     
class C(B):

    def m1(self):
        val = self.m1() + 20
        return val

obj = C()

print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[42], line 22
#      18         return val
#      20 obj = C()
# ---> 22 print(obj.m1())
#
# Cell In[42], line 17, in C.m1(self)
#      16 def m1(self):
# ---> 17     val = self.m1() + 20
#      18     return val
#
# Cell In[42], line 17, in C.m1(self)
#      16 def m1(self):
# ---> 17     val = self.m1() + 20
#      18     return val
#
#     [... skipping similar frames: C.m1 at line 17 (2975 times)]
#
# Cell In[42], line 17, in C.m1(self)
#      16 def m1(self):
# ---> 17     val = self.m1() + 20
#      18     return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ## `Polymorphism`
# - method Overriding
# - method overloading (does not work in python)
# - operator Overloading

# %%
 #method overloading
#Multiple Inheritance
class Product:   # parent ckass 1
    def review(self):
        print("Produt customer review")

class Phone:  # parent class 2

    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera
    
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone, Product):  # child class
    pass

s= Smartphone(20000,'Iphone', '13mp')
s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Produt customer review

# %%
#method overloading
#doesnot works in python it can done using *args or default arguments
class Shape:

    def area(self,radius):
        return 3.1415*radius**2
    
    def area(self,l,b):
        return l*b

s = Shape()
s.area(2)
s.area(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 12
#       9         return l*b
#      11 s = Shape()
# ---> 12 s.area(2)
#      13 s.area(1,2)
#
# TypeError: Shape.area() missing 1 required positional argument: 'b'

# %%
#Operator overloading - Operator behave differently if you vary input
print('Hello' + 'word')

print(4+5)

print([1,2,3] + [4,5])
# Out:
# Helloword
# 9
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## `Abstraction`

# %%
from abc import ABC, abstractmethod

class Bankapp(ABC):

    def database(self):
        print('connect to database')
    
    @abstractmethod
    def security(self):
        pass

class MobileApp(Bankapp): # -> works it implements abstract method of the abstract class 

    def mobile_login(self):
        print('Login into mobile')

    def security(self):
        print("implement security")

class Webapp(Bankapp):   # -> doesnot work

    def web_login(self):
        print("login to webapp")

# %%
mob = MobileApp()

# %%
web = Webapp()   # -> thows error because Webapp doesnot implement abstractmethod of Bankapp so it cannot inherit from Bankapp. it must implement the abstract method i.e. security method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 web = Webapp()   # -> thows error because Webapp doesnot implement abstractmethod of Bankapp so it cannot inherit from Bankapp. it must implement the abstract method i.e. security method
#
# TypeError: Can't instantiate abstract class Webapp without an implementation for abstract method 'security'
