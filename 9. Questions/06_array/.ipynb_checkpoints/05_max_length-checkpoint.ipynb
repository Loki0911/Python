# %%
# Given a string, find the length of the longest substring
# without repeating characters.

# Examples:
# Given "abcabcbb", the answer is "abc", which the length is 3.
# Given "bbbbb", the answer is "b", with the length of 1.
# Given "pwwkew", the answer is "wke", with the length of 3.

# %%
str2='abcabcdeabcddbac'

def longest_non_repeat(str1):
    i=0
    max_len=1
    for i,c in enumerate(str1):
        start_at=i
        sub_str=[]
        while (start_at<len(str1)) and (str1[start_at] not in sub_str):
            sub_str.append(str1[start_at])
            start_at+=1
        if len(sub_str)>max_len:
            max_len=len(sub_str)
        print(sub_str)
    return max_len
longest_non_repeat(str2)
# Out:
# ['a', 'b', 'c']
# ['b', 'c', 'a']
# ['c', 'a', 'b']
# ['a', 'b', 'c', 'd', 'e']
# ['b', 'c', 'd', 'e', 'a']
# ['c', 'd', 'e', 'a', 'b']
# ['d', 'e', 'a', 'b', 'c']
# ['e', 'a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd']
# ['b', 'c', 'd']
# ['c', 'd']
# ['d']
# ['d', 'b', 'a', 'c']
# ['b', 'a', 'c']
# ['a', 'c']
# ['c']
# 5
