# %%
# Write a Python program to iterate over dictionaries using for loops.

# %%
d = {'x': 10, 'y': 20, 'z': 30}
for dict_keys,dict_val in d.items():
    print(f" {dict_keys} -> {dict_val}")
# Out:
#  x -> 10
#  y -> 20
#  z -> 30
