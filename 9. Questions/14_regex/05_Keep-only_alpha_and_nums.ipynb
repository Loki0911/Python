# %%
# Write a Python program to remove everything except alphanumeric characters from a string.
# Input
# '**//Python Exercises// - 12. '
# Output
# PythonExercises12

# %%
import re
text='**//Python Exercises// - 12. '
pattern=re.compile('[\W_]+')
print(pattern.sub('',text))
# Out:
# PythonExercises12
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\lokes\AppData\Local\Temp\ipykernel_12696\4194862915.py:3: SyntaxWarning: invalid escape sequence '\W'
#   pattern=re.compile('[\W_]+')
