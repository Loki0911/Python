# %%
# Write a Python program to remove leading zeros from an IP address.
# Input
# "216.08.094.196"
# Output
# 216.8.94.196

# %%
import re
ip = "216.08.094.196"
string = re.sub('\.[0]*', '.', ip)
print(string)
# Out:
# 216.8.94.196
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\lokes\AppData\Local\Temp\ipykernel_33272\2157949588.py:3: SyntaxWarning: invalid escape sequence '\.'
#   string = re.sub('\.[0]*', '.', ip)
