# %%
# Remove all whitespaces from a string
# 
# Input
# ' Python    Exercises '
# Output
# PythonExercises

# %%
import re
text=' Python    Exercises '
print('Orginal text = ',text)
print("Without extra spaces:",re.sub(r'\s+', '',text))
# Out:
# Orginal text =   Python    Exercises
# Without extra spaces: PythonExercises
