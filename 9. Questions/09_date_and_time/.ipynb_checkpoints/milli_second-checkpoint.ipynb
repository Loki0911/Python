# %%
# Write a Python program to get current time in milliseconds in Python

# %%
import time
mil_sec=int(round(time.time()*1000))
print(mil_sec)
# Out:
# 1758856421336
