# %%
with open("initialdata.txt",encoding="utf-8") as f:
    data=f.read()

# %%
chunks=data.split("\n\n")
chunks=[c for c in chunks if len(c)>5]

# %%
def pharse_chunk(chunk):
    chunk=chunk.strip()
    lines=chunk.split("\n")
    user_name=lines[0]
    posts=int(lines[1].split("post")[0].replace(",",""))
    no_of_followers=float(lines[2].split("follower")[0].replace(",","").replace("K","").replace("M",""))
    if ("K" in lines[2]):
        no_of_followers=int(no_of_followers*1000)
    elif ("M" in lines[2]):
        no_of_followers=int(no_of_followers*1000000)
    else:
        no_of_followers=int(no_of_followers)
    following=float(lines[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
    if ("K" in lines[3]):
        following=int(following*1000)
    elif ("M" in lines[3]):
        following=int(following*1000000)
    else:
        following=int(following)
    name=lines[4]
    if(len(lines)>5):
        type_of_page=lines[5]
        bio="\n".join(lines[6:])
    else:
        type_of_page="Not mentioned"
        bio=""
   # print(user_name,posts,no_of_followers,following,name,type_of_page,bio,sep="\n")
    return({"User Name":user_name,
            "Posts":posts,
            "Number of followers":no_of_followers,
            "Following":following,
            "Name":name,
            "Type of Page": type_of_page,
            "Bio":bio})

# %%
all_chunks=[]
for chunk in chunks:
    pharsed_chunk=pharse_chunk(chunk)
    all_chunks.append(pharsed_chunk)

# %%
import json
s=json.dumps(all_chunks,indent=4)

# %%
#for maximum numbers of posts

maxm=0
for chunk in all_chunks:
    if (maxm<chunk['Posts']):
        maxm=chunk['Posts']
        chunk_with_maxm_posts=chunk
print(chunk_with_maxm_posts)
# Out:
# {'User Name': 'startuphub_blr', 'Posts': 2300, 'Number of followers': 45000, 'Following': 120, 'Name': 'Startup Hub Bangalore', 'Type of Page': 'Media', 'Bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %%
#Who has maximum followers
max_followers=0
for chunk in all_chunks:
    if(max_followers<chunk['Number of followers']):
        max_followers=chunk['Number of followers']
        chunk_with_maxm_followers=chunk
print(chunk_with_maxm_followers)
# Out:
# {'User Name': '_anujsinghal', 'Posts': 1785, 'Number of followers': 681000, 'Following': 248, 'Name': 'Anuj Singhal', 'Type of Page': 'Digital creator', 'Bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %%
#Who follows Maximum peoples
max_following=0
for chunk in all_chunks:
    if(max_following<chunk['Following']):
        max_following=chunk['Following']
        chunk_with_maxm_following=chunk
print(chunk_with_maxm_following)
# Out:
# {'User Name': 'katiasales2220', 'Posts': 107, 'Number of followers': 219, 'Following': 1401, 'Name': 'Katia Sales', 'Type of Page': 'Alfabetização e Reforço Escolar', 'Bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %%
#How many categories are there
categories=[]
for chunk in all_chunks:
    categories.append(chunk["Type of Page"])
categories=list(set(categories))
print(len(categories))
# Out:
# 13
